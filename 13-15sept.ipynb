# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\vikas\\Downloads\\raw_data.csv")
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9     NaN                  NaN         NaN                            NaN
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df.loc[9]=[210,'Jim Carry','1/1/1970','jimcarry@gmail.com','Male','Amazon','USA',12349.556,23652]
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018                            NaN
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018                            NaN
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df.at[3,'email']='graeme.crosisier@gmail.com'
df.at[6,'email']='modesta.batterson@gmail.com'
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['Country'].unique()
# Out:
# array(['India', 'USA', 'UAS', 'Canada', nan, 'Russia'], dtype=object)

# %%
df['Country'].replace({'UAS':'USA'},inplace=True)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['Country'].unique()
# Out:
# array(['India', 'USA', 'Canada', nan, 'Russia'], dtype=object)

# %%
df['Country'].nunique()
# Out:
# 4

# %%
df['Country'].fillna(df['Country'].mode()[0],inplace=True)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df.dtypes
# Out:
# id                    float64
# Employee Full Name     object
# DOB                    object
# email                  object
# gender                 object
# Company                object
# Country                object
# Income.1               object
# Income.2              float64
# dtype: object

# %%
df['Income.1']=df['Income.1'].str.replace("$","")
df
# Out:
# C:\Users\vikas\AppData\Local\Temp/ipykernel_10060/4277178757.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Income.1']=df['Income.1'].str.replace("$","")
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# ...

# %%
df['Income.1']=df['Income.1'].replace("",np.nan)
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     object
#  8   Income.2            18 non-null     float64
# dtypes: float64(2), object(7)
# memory usage: 1.5+ KB

# %%
df['Income.1']=df['Income.1'].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  20 non-null     float64
#  1   Employee Full Name  20 non-null     object
#  2   DOB                 20 non-null     object
#  3   email               20 non-null     object
#  4   gender              20 non-null     object
#  5   Company             20 non-null     object
#  6   Country             20 non-null     object
#  7   Income.1            13 non-null     float64
#  8   Income.2            18 non-null     float64
# dtypes: float64(3), object(6)
# memory usage: 1.5+ KB

# %%
df['Income.1'].fillna(df['Income.1'].mean(),inplace=True)

# %%
df['Income.2'].fillna(df['Income.2'].mean(),inplace=True)

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df['total income'] = np.ceil(df['Income.1']) + (df['Income.2'])
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9/20/2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11/18/2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9/29/2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4/19/2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4/26/2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3/28/2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12/18/2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1/16/2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1/1/1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4/15/2018                caudena@nba.com
# 11  212.0          Dame Povele   6/26/2018         dpoveleb@bloglovin.com
# ...

# %%
df
# Out:
#        id   Employee Full Name         DOB                          email  \
# 0   201.0          Salim Pound  02-12-2018            spound0@spotify.com
# 1   202.0       Madelene Lutas   9_20_2018                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne  11_18_2018   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier   9_29_2018     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic   4_19_2018        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman   4_26_2018        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson   3_28_2018    modesta.batterson@gmail.com
# 7   208.0          Melina Boon  12_18_2017               mboon7@weibo.com
# 8   209.0            Nomi Warn   1_16_2018               nwarn8@sogou.com
# 9   210.0            Jim Carry    1_1_1970             jimcarry@gmail.com
# 10  211.0       Charleen Auden   4_15_2018                caudena@nba.com
# 11  212.0          Dame Povele   6_26_2018         dpoveleb@bloglovin.com
# ...

# %%
## replace "/" with '-' to bring DOB in same format
df['DOB']=df['DOB'].str.replace("/","-")

# %%
date_format= "%m-%d-%Y"
df['DOB']=pd.to_datetime(df['DOB'], format=date_format)

df.head()
# Out:
#       id Employee Full Name        DOB                         email  gender  \
# 0  201.0        Salim Pound 2018-02-12           spound0@spotify.com    Male
# 1  202.0     Madelene Lutas 2018-09-20                mlutas1@si.edu  Female
# 2  203.0   Dolli Swanbourne 2018-11-18  dswanbourne2@istockphoto.com  Female
# 3  204.0    Graeme Croisier 2018-09-29    graeme.crosisier@gmail.com    Male
# 4  205.0     Jillana Physic 2018-04-19       jphysic4@yellowbook.com  Female
#
#      Company Country      Income.1  Income.2  total income
# 0     Google   India  46476.638081     529.0       47006.0
# 1     Amazon     USA  54174.687948     720.0       54895.0
# 2      Intel     USA  43467.240728     234.0       43702.0
# 3  Accenture  Canada  46784.630879     657.0       47442.0
# 4  Accenture   India  57486.495560    1947.0       59434.0

# %%
#2
df['Employee Full Name'].str.split(" ",expand=True)
# Out:
#             0            1
# 0       Salim        Pound
# 1    Madelene        Lutas
# 2       Dolli   Swanbourne
# 3      Graeme     Croisier
# 4     Jillana       Physic
# 5      Anetta     Yokelman
# 6     Modesta    Batterson
# 7      Melina         Boon
# 8        Nomi         Warn
# 9         Jim        Carry
# 10   Charleen        Auden
# 11       Dame       Povele
# 12      Jesse  Engelbrecht
# 13      Camey     Barensen
# 14  Alexandro       Sember
# 15     Myrtia        Towne
# 16       Shay    Cakebread
# 17      Nerta    McCutheon
# 18      Patin     Mitchely
# 19    Malinda  Heistermann

# %%
df["First_name"]=df["Employee Full Name"].str.split(" ").str.get(0)
df["Last_name"]=df["Employee Full Name"].str.split(" ").str.get(1)
df
# Out:
#        id   Employee Full Name        DOB                          email  \
# 0   201.0          Salim Pound 2018-02-12            spound0@spotify.com
# 1   202.0       Madelene Lutas 2018-09-20                 mlutas1@si.edu
# 2   203.0     Dolli Swanbourne 2018-11-18   dswanbourne2@istockphoto.com
# 3   204.0      Graeme Croisier 2018-09-29     graeme.crosisier@gmail.com
# 4   205.0       Jillana Physic 2018-04-19        jphysic4@yellowbook.com
# 5   206.0      Anetta Yokelman 2018-04-26        ayokelman5@berkeley.edu
# 6   207.0    Modesta Batterson 2018-03-28    modesta.batterson@gmail.com
# 7   208.0          Melina Boon 2017-12-18               mboon7@weibo.com
# 8   209.0            Nomi Warn 2018-01-16               nwarn8@sogou.com
# 9   210.0            Jim Carry 1970-01-01             jimcarry@gmail.com
# 10  211.0       Charleen Auden 2018-04-15                caudena@nba.com
# 11  212.0          Dame Povele 2018-06-26         dpoveleb@bloglovin.com
# ...

# %%
#3 move first and last name column to the 1st and 2nd position of dataset
column_to_move=df['First_name']
df=df.drop('First_name',axis=1)
df.insert(1,'First_name',column_to_move)
df
# Out:
#        id First_name   Employee Full Name        DOB  \
# 0   201.0      Salim          Salim Pound 2018-02-12
# 1   202.0   Madelene       Madelene Lutas 2018-09-20
# 2   203.0      Dolli     Dolli Swanbourne 2018-11-18
# 3   204.0     Graeme      Graeme Croisier 2018-09-29
# 4   205.0    Jillana       Jillana Physic 2018-04-19
# 5   206.0     Anetta      Anetta Yokelman 2018-04-26
# 6   207.0    Modesta    Modesta Batterson 2018-03-28
# 7   208.0     Melina          Melina Boon 2017-12-18
# 8   209.0       Nomi            Nomi Warn 2018-01-16
# 9   210.0        Jim            Jim Carry 1970-01-01
# 10  211.0   Charleen       Charleen Auden 2018-04-15
# 11  212.0       Dame          Dame Povele 2018-06-26
# 12  213.0      Jesse    Jesse Engelbrecht 2018-04-16
# 13  214.0      Camey       Camey Barensen 2018-08-21
# 14  215.0  Alexandro     Alexandro Sember 2018-04-08
# 15  216.0     Myrtia         Myrtia Towne 2018-02-14
# 16  217.0       Shay       Shay Cakebread 2018-09-27
# ...

# %%
columns_to_move=df['Last_name']
df=df.drop('Last_name',axis=1)
df.insert(2,'Last_name',columns_to_move)
df
# Out:
#        id First_name    Last_name   Employee Full Name        DOB  \
# 0   201.0      Salim        Pound          Salim Pound 2018-02-12
# 1   202.0   Madelene        Lutas       Madelene Lutas 2018-09-20
# 2   203.0      Dolli   Swanbourne     Dolli Swanbourne 2018-11-18
# 3   204.0     Graeme     Croisier      Graeme Croisier 2018-09-29
# 4   205.0    Jillana       Physic       Jillana Physic 2018-04-19
# 5   206.0     Anetta     Yokelman      Anetta Yokelman 2018-04-26
# 6   207.0    Modesta    Batterson    Modesta Batterson 2018-03-28
# 7   208.0     Melina         Boon          Melina Boon 2017-12-18
# 8   209.0       Nomi         Warn            Nomi Warn 2018-01-16
# 9   210.0        Jim        Carry            Jim Carry 1970-01-01
# 10  211.0   Charleen        Auden       Charleen Auden 2018-04-15
# 11  212.0       Dame       Povele          Dame Povele 2018-06-26
# 12  213.0      Jesse  Engelbrecht    Jesse Engelbrecht 2018-04-16
# ...

# %%
df=df.drop('Employee Full Name',axis=1)
df
# Out:
#        id First_name    Last_name        DOB                          email  \
# 0   201.0      Salim        Pound 2018-02-12            spound0@spotify.com
# 1   202.0   Madelene        Lutas 2018-09-20                 mlutas1@si.edu
# 2   203.0      Dolli   Swanbourne 2018-11-18   dswanbourne2@istockphoto.com
# 3   204.0     Graeme     Croisier 2018-09-29     graeme.crosisier@gmail.com
# 4   205.0    Jillana       Physic 2018-04-19        jphysic4@yellowbook.com
# 5   206.0     Anetta     Yokelman 2018-04-26        ayokelman5@berkeley.edu
# 6   207.0    Modesta    Batterson 2018-03-28    modesta.batterson@gmail.com
# 7   208.0     Melina         Boon 2017-12-18               mboon7@weibo.com
# 8   209.0       Nomi         Warn 2018-01-16               nwarn8@sogou.com
# 9   210.0        Jim        Carry 1970-01-01             jimcarry@gmail.com
# 10  211.0   Charleen        Auden 2018-04-15                caudena@nba.com
# ...

# %%
### average salary analysis

piv=pd.pivot_table(df,values='total income',index=['Country','Company'], aggfunc=np.mean)
piv
# Out:
#                    total income
# Country Company
# Canada  Accenture  47442.000000
#         Amazon     58113.333333
#         Google     44238.000000
# India   Accenture  59434.000000
#         Amazon     41937.000000
#         Google     49924.666667
#         Intel      43960.000000
# Russia  Amazon      9054.000000
#         Google     44036.000000
#         Intel      45032.000000
# USA     Accenture  48040.000000
#         Amazon     50975.444444
#         Intel      43702.000000
